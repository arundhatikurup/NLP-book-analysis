# %% [markdown]
# Statistical Analysis of 'Wings of Fire' by Dr.Kalam using Natural Language Processing(NLP)

# %% [markdown]
# Tokenizing  Chapter 1 contents into constituting words

# %%
import nltk
file_content = open("chap1.txt").read()
tokens = nltk.word_tokenize(file_content)
print "Total No:Of words:",len(tokens)
print tokens
mytext = nltk.Text(tokens)
# Out:
# Total No:Of words: 3453
# ...

# %% [markdown]
# Frequency distribution of tokens

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
def graph():
  f = open("chap1.txt", "r")
  inputfile = f.read()
  tokens = nltk.tokenize.word_tokenize(inputfile)
  fd = nltk.FreqDist(tokens)
  fd.plot(30,cumulative=False)
graph()

# %% [markdown]
# Frequency distribution after removing punctuations, stopwords.
# The top 20 words are analysed.

# %%
import nltk
import numpy as np
import matplotlib
from nltk.corpus import stopwords


def getTopWords(words,n):
    unique, counts = np.unique(words, return_counts=True)
    args = np.argsort(counts)[::-1]
    unique = unique[args]
    counts = counts[args]
    
    w=[]
    wc=[]
    topWords = []
    for i in range(n):
        word = unique[i]
        word_count = counts[i]
        w.append(word)
        wc.append(word_count)
        topWords.append((word,word_count))
    print w
    print ""
    return topWords
    
def removePunct(words):
    cleanWords = []
    for word in words:
        word = word.lower()
        word = list(word)
        word = [l for l in word if 'a'<=l<='z']
        word = ''.join(word)
        cleanWords.append(word)
    return cleanWords


def removeStopWords(words):
    stop_words = set(stopwords.words('english'))
    stop_words = set([str(x) for x in stop_words])
    stop_words = list(stop_words)
    stop_words.append('')
    stop_words.append(' ')

    words = [word for word in words if word not in stop_words]
    words = list(words)
    return words

file_content = open("chap1.txt").read()
tokens = nltk.word_tokenize(file_content)
a=removePunct(tokens)
b=removeStopWords(a)

j=len(b)
print "No:of words after removing punctuation and stopwords :",j    
print ""

#print b

c=getTopWords(b,20)
print "The top 20 words and their frequency :"
print ""
print c

fd = nltk.FreqDist(b)
fd.plot(20,cumulative=False)
# Out:
# No:of words after removing punctuation and stopwords : 1582
#
# ['rameswaram', 'father', 'would', 'jallaluddin', 'one', 'used', 'people', 'teacher', 'temple', 'samsuddin', 'sastry', 'home', 'mosque', 'made', 'house', 'every', 'mother', 'childhood', 'children', 'always']
#
# The top 20 words and their frequency :
#
# [('rameswaram', 22), ('father', 22), ('would', 19), ('jallaluddin', 15), ('one', 11), ('used', 11), ('people', 10), ('teacher', 9), ('temple', 9), ('samsuddin', 8), ('sastry', 8), ('home', 8), ('mosque', 7), ('made', 7), ('house', 7), ('every', 7), ('mother', 7), ('childhood', 6), ('children', 6), ('always', 6)]

# %% [markdown]
# The above plot gives intresting insights into the chapter under consideration. The word 'father' and 'rameswaram' occurs 22 times each which sigifies the deep impact these had on Dr.Kalam as a child.Similarly the words 'jallaludhin' ,'samsuddin','temple' ,'mosque', 'mother' signify their influence as well on Dr.Kalam as a small boy as inferred from the frequency with which these words occur in the chapter

# %%
import nltk
import numpy as np
import nltk.draw
from nltk.corpus import stopwords


def getTopWords(words,n):
    unique, counts = np.unique(words, return_counts=True)
    args = np.argsort(counts)[::-1]
    unique = unique[args]
    counts = counts[args]
    
    w=[]
    wc=[]
    topWords = []
    for i in range(n):
        word = unique[i]
        word_count = counts[i]
        w.append(word)
        wc.append(word_count)
        topWords.append((word,word_count))
    return w

to_plot = []
z=getTopWords(b,20)
print z
file_content = open("chap1.txt").read()
tokens = nltk.word_tokenize(file_content)
mytext = nltk.Text(tokens)  
for word in z:
        to_plot.append(word)
        
mytext.dispersion_plot(to_plot)
# Out:
# ['rameswaram', 'father', 'would', 'jallaluddin', 'one', 'used', 'people', 'teacher', 'temple', 'samsuddin', 'sastry', 'home', 'mosque', 'made', 'house', 'every', 'mother', 'childhood', 'children', 'always']

# %% [markdown]
# The above shows the dispersion plot for the most frequently occuring words

# %% [markdown]
# A sample text is taken from the chapter and the words of the text are tagged into nouns , verbs etc

# %%
from textblob import TextBlob

text = '''
I was born into a middle-class Tamil family in the island 
town of Rameswaram in the erstwhile Madras state. My 
father Jainulabdeen, had neither much formal education 
nor much wealth; despite these disadvantages, he possessed great 
innate wisdom and a true generosity of spirit. He found an 
ideal helpmate in my mother, Ashiamma. I do  recall the 
exact number of people she fed every day but I am quite 
certain that far more outsiders ate with us than all the 
members of our own family put together. it is very very bad.
'''

blob = TextBlob(text)
print blob.tags           # [('The', 'DT'), ('titular', 'JJ'),
                    #  ('threat', 'NN'), ('of', 'IN'), ...]

print blob.noun_phrases   # WordList(['titular threat', 'blob',
                    #            'ultimate movie monster',
                    #            'amoeba-like mass', ...])
# Out:
# [('I', u'PRP'), ('was', u'VBD'), ('born', u'VBN'), ('into', u'IN'), ('a', u'DT'), ('middle-class', u'JJ'), ('Tamil', u'NNP'), ('family', u'NN'), ('in', u'IN'), ('the', u'DT'), ('island', u'NN'), ('town', u'NN'), ('of', u'IN'), ('Rameswaram', u'NNP'), ('in', u'IN'), ('the', u'DT'), ('erstwhile', u'NN'), ('Madras', u'NNP'), ('state', u'NN'), ('My', u'PRP$'), ('father', u'NN'), ('Jainulabdeen', u'NNP'), ('had', u'VBD'), ('neither', u'RB'), ('much', u'JJ'), ('formal', u'JJ'), ('education', u'NN'), ('nor', u'CC'), ('much', u'JJ'), ('wealth', u'NN'), ('despite', u'IN'), ('these', u'DT'), ('disadvantages', u'NNS'), ('he', u'PRP'), ('possessed', u'VBD'), ('great', u'JJ'), ('innate', u'JJ'), ('wisdom', u'NN'), ('and', u'CC'), ('a', u'DT'), ('true', u'JJ'), ('generosity', u'NN'), ('of', u'IN'), ('spirit', u'NN'), ('He', u'PRP'), ('found', u'VBD'), ('an', u'DT'), ('ideal', u'JJ'), ('helpmate', u'NN'), ('in', u'IN'), ('my', u'PRP$'), ('mother', u'NN'), ('Ashiamma', u'NNP'), ('I', u'PRP'), ('do',
# ...

# %% [markdown]
# Sentiment Analysis is performed for each sentence of the sample text from the chapter.

# %%
i=1
for sentence in blob.sentences:
    print "sentence",i,":",(sentence.sentiment.polarity)
    i=i+1
# Out:
# sentence 1 : 0.0
# sentence 2 : 0.3875
# sentence 3 : 0.9
# sentence 4 : 0.332857142857
# sentence 5 : -0.91

# %% [markdown]
# The sample text is converted to the language of choice using a simple function translate() (Here , to hindi) successfully using the blob package

# %%
blob.translate(to="hi")
# Out:
# TextBlob("मैं द्वीप में एक मध्यम वर्ग के तमिल परिवार में पैदा हुआ था
# पूर्व मद्रास राज्य में रामेश्वरम का शहर मेरे
# पिता जैनुलबाबीन ने न तो बहुत औपचारिक शिक्षा की
# और न ही बहुत धन; इन नुकसान के बावजूद, वह महान था
# सहज ज्ञान और भावना की एक असली उदारता उन्होंने पाया एक
# मेरी मां में आदर्श सहवास, आशािमा मुझे याद है
# वह हर दिन खिलाती लोगों की सटीक संख्या परन्तु मैं काफी है
# यह निश्चित है कि सभी बाहर के लोगों ने हमारे साथ खाया
# हमारे परिवार के सदस्यों ने एक साथ रखा। यह बहुत बहुत बुरा है")
